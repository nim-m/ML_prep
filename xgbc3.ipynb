# %% [markdown]
# # data curation (CBCL)

# %%
import pandas as pd

# %%
# import deriv_cog_impair dataset
less5 = pd.read_csv("less5.csv")
cbcl = pd.read_csv("cbcl_1_5-2023-07-21.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6844\3226951148.py:2: DtypeWarning: Columns (138,164,165,166,198,200,386,504,509,531,543,548,555,560,754,757,759,762,764) have mixed types. Specify dtype option on import or set low_memory=False.
#   less5 = pd.read_csv("less5.csv")

# %%
# select cbcl1-5 parameters

cbcl_items = [
    "subject_sp_id",
    "deriv_cog_impair",
    "cbcl_validity_flag",
    "q001_aches_pains",
    "q002_acts_too_young",
    "q003_afraid_new",
    "q004_avoids_eye",
    "q005_concentrate",
    "q006_restless_hyperactive",
    "q007_out_of_place",
    "q008_waiting",
    "q009_chews_edible",
    "q010_clings",
    "q011_seeks_help",
    "q012_constipated",
    "q013_cries",
    "q014_cruel_to_animals",
    "q015_defiant",
    "q016_demands_met",
    "q017_destroys_own_things",
    "q018_destroys_family_things",
    "q019_diarrhea",
    "q020_disobedient",
    "q021_change_routine",
    "q022_sleep_alone",
    "q023_answer_people",
    "q024_eat_well",
    "q025_get_along",
    "q026_have_fun",
    "q027_feel_guilty",
    "q028_go_out_home",
    "q029_easily_frustrated",
    "q030_easily_jealous",
    "q031_eats_not_food",
    "q032_fears_animals",
    "q033_feelings_hurt",
    "q034_accident_prone",
    "q035_gets_fights",
    "q036_gets_into_everything",
    "q037_upset_separated",
    "q038_trouble_sleep",
    "q039_headaches",
    "q040_hits_others",
    "q041_holds_breath",
    "q042_hurts_animals",
    "q043_unhappy_reason",
    "q044_angry_moods",
    "q045_nausea",
    "q046_twitching",
    "q047_nervous_tense",
    "q048_nightmares",
    "q049_overeating",
    "q050_overtired",
    "q051_panic_no_reason",
    "q052_painful_bowel",
    "q053_attacks_people",
    "q054_picks_nose",
    "q055_plays_sex_parts",
    "q056_clumsy",
    "q057_problems_eyes",
    "q058_punishment_behav_change",
    "q059_shifts_activity",
    "q060_rashes",
    "q061_refuses_eat",
    "q062_refuses_active_games",
    "q063_rocks_head",
    "q064_resists_bed",
    "q065_resists_toilet_training",
    "q066_screams",
    "q067_unresponsive_affection",
    "q068_self_conscious",
    "q069_selfish",
    "q070_little_affection",
    "q071_little_interest_around",
    "q072_little_fear_getting_hurt",
    "q073_too_shy",
    "q074_sleeps_less",
    "q075_plays_bowel_movements",
    "q076_speech_problem",
    "q077_stares_space",
    "q078_stomachaches",
    "q079_sadness_excitement",
    "q080_strange_behavior",
    "q081_stubborn",
    "q082_changes_mood",
    "q083_sulks",
    "q084_talks_sleep",
    "q085_temper_tantrums",
    "q086_concerned_neatness",
    "q087_fearful",
    "q088_uncooperative",
    "q089_underactive",
    "q090_unhappy",
    "q091_loud",
    "q092_upset_new_people",
    "q093_vomiting",
    "q094_wakes_up_night",
    "q095_wanders_away",
    "q096_wants_attention",
    "q097_whining",
    "q098_withdrawn",
    "q099_worries",
    "emotionally_reactive_raw_score",
    "emotionally_reactive_t_score",
    "emotionally_reactive_percentile",
    "emotionally_reactive_range",
    "anxious_depressed_raw_score",
    "anxious_depressed_t_score",
    "anxious_depressed_percentile",
    "anxious_depressed_range",
    "somatic_complaints_raw_score",
    "somatic_complaints_t_score",
    "somatic_complaints_percentile",
    "somatic_complaints_range",
    "withdrawn_raw_score",
    "withdrawn_t_score",
    "withdrawn_percentile",
    "withdrawn_range",
    "sleep_problems_raw_score",
    "sleep_problems_t_score",
    "sleep_problems_percentile",
    "sleep_problems_range",
    "attention_problems_raw_score",
    "attention_problems_t_score",
    "attention_problems_percentile",
    "attention_problems_range",
    "aggressive_behavior_raw_score",
    "aggressive_behavior_t_score",
    "aggressive_behavior_percentile",
    "aggressive_behavior_range",
    "internalizing_problems_raw_score",
    "internalizing_problems_t_score",
    "internalizing_problems_percentile",
    "internalizing_problems_range",
    "externalizing_problems_raw_score",
    "externalizing_problems_t_score",
    "externalizing_problems_percentile",
    "externalizing_problems_range",
    "total_problems_raw_score",
    "total_problems_t_score",
    "total_problems_percentile",
    "total_problems_range",
    "stress_problems_raw_score",
    "stress_problems_t_score",
    "stress_problems_percentile",
    "stress_problems_range",
    "other_problems_raw_score",
    "dsm5_depressive_problems_raw_score",
    "dsm5_depressive_problems_t_score",
    "dsm5_depressive_problems_percentile",
    "dsm5_depressive_problems_range",
    "dsm5_anxiety_problems_raw_score",
    "dsm5_anxiety_problems_t_score",
    "dsm5_anxiety_problems_percentile",
    "dsm5_anxiety_problems_range",
    "dsm5_autism_spectrum_problems_raw_score",
    "dsm5_autism_spectrum_problems_t_score",
    "dsm5_autism_spectrum_problems_percentile",
    "dsm5_autism_spectrum_problems_problems_range",
    "dsm5_attention_deficit_hyperactivity_raw_score",
    "dsm5_attention_deficit_hyperactivity_t_score",
    "dsm5_attention_deficit_hyperactivity_percentile",
    "dsm5_attention_deficit_hyperactivity_range",
    "dsm5_oppositional_defiant_raw_score",
    "dsm5_oppositional_defiant_t_score",
    "dsm5_oppositional_defiant_percentile",
    "dsm5_oppositional_defiant_range"
]

cbcl_cog_imp = less5[cbcl_items]

# %%
cbcl_cog_imp.shape
# Out:
# (27088, 167)

# %%
cbcl_cog_imp['deriv_cog_impair'].value_counts(dropna=False)
# Out:
# deriv_cog_impair
# 0.0    12366
# NaN     8257
# 1.0     6465
# Name: count, dtype: int64

# %%
# drop rows with more than 20 missing parameters
threshold = len(cbcl_cog_imp.columns) - 20
df_clean = cbcl_cog_imp.dropna(thresh=threshold)

# %%
# Drop rows where 'cbcl_validity_flag' column is 1.0 (NOT IN THE PARENT DATASET, WE NEED THOSE POINTS WHEN PREDICTING!)
# df_clean = df_clean[df_clean['cbcl_validity_flag'] != 1.0]

# Drop rows where 'deriv_cog_impair' column is NaN
# df_clean = df_clean.dropna(subset=['deriv_cog_impair'])

# %%
df_clean['deriv_cog_impair'].value_counts(dropna=False)
# Out:
# deriv_cog_impair
# 1.0    1859
# 0.0     782
# NaN       3
# Name: count, dtype: int64

# %%
df_clean['cbcl_validity_flag'].value_counts(dropna=False)
# Out:
# cbcl_validity_flag
# NaN    2640
# 1.0       4
# Name: count, dtype: int64

# %%
# check final missing values
for col in df_clean.columns:
    print(col, ":", df_clean[col].isna().sum())
# Out:
# subject_sp_id : 0
# deriv_cog_impair : 3
# cbcl_validity_flag : 2640
# q001_aches_pains : 5
# q002_acts_too_young : 5
# q003_afraid_new : 5
# q004_avoids_eye : 4
# q005_concentrate : 3
# q006_restless_hyperactive : 7
# q007_out_of_place : 6
# q008_waiting : 4
# q009_chews_edible : 5
# q010_clings : 3
# q011_seeks_help : 9
# q012_constipated : 2
# q013_cries : 7
# q014_cruel_to_animals : 6
# q015_defiant : 8
# q016_demands_met : 1
# q017_destroys_own_things : 4
# q018_destroys_family_things : 6
# q019_diarrhea : 5
# q020_disobedient : 4
# q021_change_routine : 9
# q022_sleep_alone : 7
# q023_answer_people : 7
# q024_eat_well : 7
# q025_get_along : 2
# q026_have_fun : 5
# q027_feel_guilty : 1
# q028_go_out_home : 3
# q029_easily_frustrated : 5
# q030_easily_jealous : 5
# q031_eats_not_food : 5
# q032_fears_animals : 2
# q033_feelings_hurt : 2
# q034_accident_prone : 3
# q035_gets_fights : 8
# q036_gets_into_everything : 4
# q037_upset_separated : 4
# q038_trouble_sleep : 3
# ...

# %%
# one hot encoding

# Identify categorical columns
categorical_columns = [
    "q001_aches_pains", "q002_acts_too_young", "q003_afraid_new", "q004_avoids_eye", "q005_concentrate",
    "q006_restless_hyperactive", "q007_out_of_place", "q008_waiting", "q009_chews_edible", "q010_clings",
    "q011_seeks_help", "q012_constipated", "q013_cries", "q014_cruel_to_animals", "q015_defiant",
    "q016_demands_met", "q017_destroys_own_things", "q018_destroys_family_things", "q019_diarrhea",
    "q020_disobedient", "q021_change_routine", "q022_sleep_alone", "q023_answer_people", "q024_eat_well",
    "q025_get_along", "q026_have_fun", "q027_feel_guilty", "q028_go_out_home", "q029_easily_frustrated",
    "q030_easily_jealous", "q031_eats_not_food", "q032_fears_animals", "q033_feelings_hurt", "q034_accident_prone",
    "q035_gets_fights", "q036_gets_into_everything", "q037_upset_separated", "q038_trouble_sleep", "q039_headaches",
    "q040_hits_others", "q041_holds_breath", "q042_hurts_animals", "q043_unhappy_reason", "q044_angry_moods",
    "q045_nausea", "q046_twitching", "q047_nervous_tense", "q048_nightmares", "q049_overeating", "q050_overtired",
    "q051_panic_no_reason", "q052_painful_bowel", "q053_attacks_people", "q054_picks_nose", "q055_plays_sex_parts",
    "q056_clumsy", "q057_problems_eyes", "q058_punishment_behav_change", "q059_shifts_activity", "q060_rashes",
    "q061_refuses_eat", "q062_refuses_active_games", "q063_rocks_head", "q064_resists_bed", "q065_resists_toilet_training",
    "q066_screams", "q067_unresponsive_affection", "q068_self_conscious", "q069_selfish", "q070_little_affection",
    "q071_little_interest_around", "q072_little_fear_getting_hurt", "q073_too_shy", "q074_sleeps_less",
    "q075_plays_bowel_movements", "q076_speech_problem", "q077_stares_space", "q078_stomachaches", "q079_sadness_excitement",
    "q080_strange_behavior", "q081_stubborn", "q082_changes_mood", "q083_sulks", "q084_talks_sleep", "q085_temper_tantrums",
    "q086_concerned_neatness", "q087_fearful", "q088_uncooperative", "q089_underactive", "q090_unhappy", "q091_loud",
    "q092_upset_new_people", "q093_vomiting", "q094_wakes_up_night", "q095_wanders_away", "q096_wants_attention",
    "q097_whining", "q098_withdrawn", "q099_worries", "emotionally_reactive_range", "anxious_depressed_range",
    "somatic_complaints_range", "withdrawn_range", "sleep_problems_range", "attention_problems_range",
    "aggressive_behavior_range", "internalizing_problems_range", "externalizing_problems_range", "total_problems_range",
    "stress_problems_range", "dsm5_depressive_problems_range", "dsm5_anxiety_problems_range",
    "dsm5_autism_spectrum_problems_problems_range", "dsm5_attention_deficit_hyperactivity_range",
    "dsm5_oppositional_defiant_range"
]


# One-hot encode categorical columns
df_clean = pd.get_dummies(df_clean, columns=categorical_columns)

# %%
df_clean.to_csv("cbcl_cog_imp.csv", index=False)

# %% [markdown]
# # Model

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import shap

from imblearn.over_sampling import RandomOverSampler

def load_data():
    df2 = pd.read_csv('cbcl_cog_imp.csv')

    # TOTAL PREDICTION DATASET
    X2 = df2.drop(columns=['subject_sp_id','deriv_cog_impair','cbcl_validity_flag']) 
    y2 = df2['deriv_cog_impair']

    # MODEL TRAINING DATASET 
    # drop rows where target variable deriv_cog_impair is missing
    df = df2.dropna(subset=['deriv_cog_impair'])

    # Drop rows where 'cbcl_validity_flag' column is 1.0 ----------
    df = df[df['cbcl_validity_flag'] != 1.0]
    
    # Drop rows where 'deriv_cog_impair' column is NaN ------------
    df = df.dropna(subset=['deriv_cog_impair'])

    # Separate features and target variable
    X = df.drop(columns=['subject_sp_id','deriv_cog_impair','cbcl_validity_flag']) 
    y = df['deriv_cog_impair']

    # Apply random oversampling to balance the classes
    oversampler = RandomOverSampler(random_state=42)
    X_resampled, y_resampled = oversampler.fit_resample(X, y)
    
    return X_resampled, y_resampled, df, df2, y2, X2


def create_model(eval_metrics, scale_pos_weight):
    return XGBClassifier(n_estimators=100, learning_rate=0.1, eval_metric=eval_metrics, early_stopping_rounds=5, scale_pos_weight=scale_pos_weight)


def main():
    X, y, df, df2, y2, X2 = load_data()

    # Perform cross validation using StratifiedKFold
    k = 10

    eval_metrics = ["auc"]
    results = []
    confusion_matrices = []

    # Loop over each fold
    for i in range(k):
        # Split data into training and test sets for current fold
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=i)
        X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=i)
        
        eval_set = [(X_train, y_train), (X_val, y_val)]

        scale_pos_weight = len(y_train[y_train == 0]) / len(y_train[y_train == 1])

        # Create and fit model for current fold
        model = create_model(eval_metrics, scale_pos_weight)
        model.fit(X_train, y_train, eval_set=eval_set, verbose=True)

        # Evaluate model on test set for current fold
        auc_score = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
        results.append(auc_score)

        # Calculate confusion matrix for current fold
        y_pred = model.predict(X_test)
        cm = confusion_matrix(y_test, y_pred)
        confusion_matrices.append(cm)

        # Plot ROC curve for current fold
        fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
        plt.plot(fpr, tpr, label=f'Fold {i+1}')

    # Calculate average AUC score and standard deviation --------------
    avg_auc_score = np.mean(results)
    std_dev = np.std(results)

    print("\n AUC scores: \n")

    print(f"Average score: {avg_auc_score}")
    print(f"Standard deviation: {std_dev}")

    # Plot ROC curve for all folds ------------------
    plt.title('ROC Curve for all Folds')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Explain model predictions using SHAP ---------------
    explainer = shap.Explainer(model)
    shap_values = explainer.shap_values(X_test)
    
    # Plot SHAP values
    shap.summary_plot(shap_values, X_test)

    # Store predictions in a new column in the original dataframe ----------
    df2.loc[X2.index, 'ml_pred_cog_impair'] = model.predict(X2)

    # Save dataframe with new column to csv file
    df2.to_csv('cbcl_cog_imp_ML_pred.csv', index=False)


if __name__ == "__main__":
    main()
# Out:
# [0]	validation_0-auc:0.86062	validation_1-auc:0.77316
# [1]	validation_0-auc:0.87444	validation_1-auc:0.77995
# [2]	validation_0-auc:0.88456	validation_1-auc:0.79554
# [3]	validation_0-auc:0.89721	validation_1-auc:0.80629
# [4]	validation_0-auc:0.90576	validation_1-auc:0.81369
# [5]	validation_0-auc:0.91645	validation_1-auc:0.82014
# [6]	validation_0-auc:0.92008	validation_1-auc:0.82082
# [7]	validation_0-auc:0.92425	validation_1-auc:0.82136
# [8]	validation_0-auc:0.92708	validation_1-auc:0.82531
# [9]	validation_0-auc:0.93054	validation_1-auc:0.82719
# [10]	validation_0-auc:0.93614	validation_1-auc:0.82873
# [11]	validation_0-auc:0.93811	validation_1-auc:0.82819
# [12]	validation_0-auc:0.94097	validation_1-auc:0.82812
# [13]	validation_0-auc:0.94557	validation_1-auc:0.83235
# [14]	validation_0-auc:0.94835	validation_1-auc:0.83316
# [15]	validation_0-auc:0.95290	validation_1-auc:0.83606
# [16]	validation_0-auc:0.95614	validation_1-auc:0.84053
# ...
